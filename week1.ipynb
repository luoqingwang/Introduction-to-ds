# %%
import pandas as pd

# %%
df = pd.read_csv("data/bags.csv")
df
# Out:
#                    Name   Variation  DIY   Buy  Sell     Color 1   Color 2  \
# 0        acorn pochette       Brown  Yes   NFS  2400       Brown     Green
# 1           basket pack       Green  Yes   NFS  2400       Green     Green
# 2              bug cage       Green   No   NFS   122       Green     White
# 3         Bunny Day bag         NaN  Yes   NFS  2400    Colorful  Colorful
# 4    butterfly backpack        Pink   No   NFS   210        Pink    Yellow
# ..                  ...         ...  ...   ...   ...         ...       ...
# 91         travel pouch  Light blue   No   840   210  Light blue     Black
# 92         travel pouch      Purple   No   840   210      Purple     Black
# 93  traveler's backpack      Orange   No  2940   735      Orange     Beige
# 94  traveler's backpack        Blue   No  2940   735        Blue     Beige
# 95  traveler's backpack       Brown   No  2940   735       Brown     Beige
#
# ...

# %%
df.dtypes
# Out:
# Name                      object
# Variation                 object
# DIY                       object
# Buy                       object
# Sell                       int64
# Color 1                   object
# Color 2                   object
# Size                      object
# Miles Price              float64
# Source                    object
# Source Notes              object
# Seasonal Availability     object
# Version                   object
# Style                     object
# Label Themes              object
# Villager Equippable       object
# Catalog                   object
# Filename                  object
# Internal ID                int64
# Unique Entry ID           object
# dtype: object

# %%
df["Style"].value_counts()
# Out:
# Style
# Active      40
# Cute        19
# Simple      18
# Elegant     10
# Cool         8
# Gorgeous     1
# Name: count, dtype: int64

# %%
df[["Name","Variation","Color 1", "Color 2"]].value_counts()
# Out:
# Name                 Variation  Color 1  Color 2
# DAL backpack         Blue       Blue     Black      1
# outdoor backpack     Orange     Orange   Black      1
# retro sports bag     Red        White    Red        1
#                      Blue       White    Blue       1
#                      Black      Black    Yellow     1
#                                                    ..
# evening bag          Pink       Pink     Yellow     1
#                      Blue       Blue     Yellow     1
#                      Black      Black    Yellow     1
# dry bag              Yellow     Yellow   Black      1
# traveler's backpack  Orange     Orange   Beige      1
# Name: count, Length: 95, dtype: int64

# %%
df.sort_values(by='Sell', ascending=True)[:10]
# Out:
#               Name              Variation DIY  Buy  Sell   Color 1 Color 2  \
# 2         bug cage                  Green  No  NFS   122     Green   White
# 41        knapsack                  Black  No  630   157     Black   Black
# 40        knapsack                   Blue  No  630   157      Blue   Black
# 50  Mom's knapsack                      M  No  NFS   175    Yellow   Beige
# 13   crossbody bag                  White  No  700   175     White   Black
# 12   crossbody bag                 Yellow  No  700   175    Yellow   Black
# 11   crossbody bag                  Green  No  700   175     Green   Black
# 10   crossbody bag                   Pink  No  700   175      Pink   Black
# 51  Mom's knapsack                Flowers  No  NFS   175      Gray   Beige
# 53  Mom's knapsack  Colorful quilt design  No  NFS   175  Colorful   Beige
#
#    Size  Miles Price   Source Source Notes Seasonal Availability Version  \
# ...

# %%
source = df[df["Source"]=="Crafting"]
source
# Out:
#                        Name Variation  DIY  Buy   Sell     Color 1   Color 2  \
# 0            acorn pochette     Brown  Yes  NFS   2400       Brown     Green
# 1               basket pack     Green  Yes  NFS   2400       Green     Green
# 3             Bunny Day bag       NaN  Yes  NFS   2400    Colorful  Colorful
# 6   cherry-blossom pochette      Pink  Yes  NFS   2400        Pink      Pink
# 42   knitted-grass backpack     Green  Yes  NFS    400       Green     Brown
# 43                 log pack     Brown  Yes  NFS    960       Brown     Beige
# 44      maple-leaf pochette       Red  Yes  NFS   2400      Orange    Orange
# 74       shellfish pochette     White  Yes  NFS  10800       White     White
# 75       snowflake pochette     White  Yes  NFS   2400  Light blue     White
# 79            star pochette    Yellow  Yes  NFS   3000      Yellow    Yellow
#
#    Size  Miles Price    Source Source Notes Seasonal Availability Version  \
# ...

# %%
df.sort_values(by='Buy', ascending=True)[:10]
# Out:
#                       Name  Variation DIY   Buy  Sell Color 1 Color 2 Size  \
# 18                 dry bag       Blue  No  1040   260    Blue   Black  1x1
# 88           town backpack        Red  No  1040   260     Red     Red  1x1
# 87           town backpack       Blue  No  1040   260    Blue    Blue  1x1
# 17                 dry bag     Yellow  No  1040   260  Yellow   Black  1x1
# 85           town backpack      Green  No  1040   260   Green   Green  1x1
# 86           town backpack     Orange  No  1040   260  Orange  Orange  1x1
# 63  pleather crossbody bag      Black  No  1120   280   Black   White  1x1
# 62  pleather crossbody bag  Navy blue  No  1120   280    Blue   Brown  1x1
# 35         hand-knit pouch      Green  No  1250   312   Green   Green  1x1
# 21             evening bag      Black  No  1250   312   Black  Yellow  1x1
#
#     Miles Price Source Source Notes Seasonal Availability Version    Style  \
# ...

# %%
df["Sell"].max()-df["Sell"].min()
# Out:
# 10678

# %%
df["Buy"] = pd.to_numeric(df["Buy"], errors='coerce')

df_num = df.dropna(subset=["Buy"])

print(df_num)
# Out:
#                    Name   Variation DIY     Buy  Sell     Color 1     Color 2  \
# 5       canvas backpack       White  No  1300.0   325       White      Orange
# 7    cloth shoulder bag        Blue  No  1400.0   350  Light blue  Light blue
# 8    cloth shoulder bag      Orange  No  1400.0   350      Orange      Orange
# 9    cloth shoulder bag       Ivory  No  1400.0   350       White       White
# 10        crossbody bag        Pink  No   700.0   175        Pink       Black
# ..                  ...         ...  ..     ...   ...         ...         ...
# 91         travel pouch  Light blue  No   840.0   210  Light blue       Black
# 92         travel pouch      Purple  No   840.0   210      Purple       Black
# 93  traveler's backpack      Orange  No  2940.0   735      Orange       Beige
# 94  traveler's backpack        Blue  No  2940.0   735        Blue       Beige
# 95  traveler's backpack       Brown  No  2940.0   735       Brown       Beige
#
# ...

# %%
df_num["Buy"].max()-df_num["Buy"].min()
# Out:
# 2310.0
